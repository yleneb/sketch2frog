# %% [markdown]
# Does the model even work??? I need to try with a simpler dataset. I suspect this may just be an inappropriate problem for this model, the shiny palette is effectively random. Although you would expect it to eventually overfit - somehow identifying which pokemon and then remembering that colour palette.
#
# Notes:
# - Model gets stuck and stops improving.
# - Noise could be a problem, PatchGan has a sigmoid so predicts [0,1]. Label noise is <code>+= 0.05 * tf.random.normal(tf.shape(y_real))</code> so cfan be outside the possible range of the discriminator. Instead try label smoothing.
# - Try a pretrained encoder and do not update the weights
# - Improve sketches to be closer to a human drawing.
# - Further data augmentations?
# - LAMBDA=100 was used for images of size 224(?) is that still correct for 128 images? Should we expect that a 70x70 patch's loss be less than the loss of a 224x224 image? In which case, we may need to change LAMBDA when we change the output image size.
# - increase model to full size for 224 (will need to resize imaghes to 256)

# %% [markdown]
# # Imports and Settings

# %%
from IPython import get_ipython
get_ipython().run_line_magic('reload_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib import cm
import pathlib
import os
import datetime
import pandas as pd
import numpy as np
import functools
import cv2
import albumentations as A
from IPython.display import display
import wandb
from wandb.keras import WandbCallback

import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow.keras.utils import plot_model

USE_WANDB = True
IS_TEST = False
NEW_DATASET = True

PATH = pathlib.Path.cwd()
DATA_DIR = PATH.parent / 'data'
MODELS_DIR = PATH.parent / 'models'
VIZ_DIR = PATH.parent / 'visualisations'

if NEW_DATASET:
    IMAGES_DIR = DATA_DIR / 'processed' / 'targets'
    SKETCH_DIR = DATA_DIR / 'processed' / 'sketches'
    
elif not NEW_DATASET:
    IMAGES_DIR = DATA_DIR / 'raw' / 'data-224'
    SKETCH_DIR = DATA_DIR / 'interim' / 'DexiNed-fuse'


RUN_NAME = datetime.datetime.now().strftime("%Y-%m-%d %H%M")
# RUN_NAME = "2021-09-14 2251"
print(RUN_NAME)
# Out:
# 2021-09-25 0014

# %%
# has a tendency to run out of gpu space
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# # mixed precision training - complicated with GANS
# policy = tf.keras.mixed_precision.Policy('mixed_float16')
# tf.keras.mixed_precision.set_global_policy(policy)

# %%
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

# model / training hyperparameters
LAMBDA = 100
EPOCHS = 300
PATCH_SIZE = 8
# label smoothing
REAL_LABEL_LOWER = 0.95
REAL_LABEL_UPPER = 1.0
G_LEARNING_RATE = 0.0002
G_BETA_1 = 0.5
D_LEARNING_RATE = 0.0002
D_BETA_1 = 0.5

# dataset parameters
# Typically, the batch size (n_batch) is set to 1.
BATCH_SIZE = 64
BUFFER_SIZE = 1000
IMAGE_SIZE = [128, 128] # originally 224x224

# dataset sizes
IMAGE_COUNT = len(list(SKETCH_DIR.glob('*.png')))
VAL_PROPORTION = 0.1
VALID_LENGTH = int(IMAGE_COUNT * VAL_PROPORTION)
TRAIN_LENGTH = IMAGE_COUNT - VALID_LENGTH

# number of batches
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE
VALIDATION_STEPS = VALID_LENGTH // BATCH_SIZE

# settings for testing for fast iteration
TEST_SIZE = None
TEST_SETTINGS = {}

if IS_TEST:
    # need to sort this line out
    # TEST_SIZE = 97 # TRAIN_LENGTH // BATCH_SIZE (8)
    TEST_SETTINGS = {'subset':True}
    EPOCHS = 2
    STEPS_PER_EPOCH = TRAIN_LENGTH // TEST_SIZE // BATCH_SIZE
    VALIDATION_STEPS = VALID_LENGTH // TEST_SIZE // BATCH_SIZE

# %%
if USE_WANDB:
    os.environ['WANDB_NOTEBOOK_NAME'] = "3. sketch2frog.ipynb"
    wandb.login()

    # Step1: Initialize W&B run
    wandb.init(
        project='sketch2frog',
        name=RUN_NAME,
        save_code=True)
# Out:
# wandb: Currently logged in as: yleneb (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">2021-09-25 0014</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yleneb/sketch2frog" target="_blank">https://wandb.ai/yleneb/sketch2frog</a><br/>
#                 Run page: <a href="https://wandb.ai/yleneb/sketch2frog/runs/v1xtzltr" target="_blank">https://wandb.ai/yleneb/sketch2frog/runs/v1xtzltr</a><br/>
#                 Run data is saved locally in <code>c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\notebooks\wandb\run-20210925_001448-v1xtzltr</code><br/><br/>

# %%
if USE_WANDB:
    # log model config to wandb
    wandb.config.update({
        "RUN_NAME": RUN_NAME,
        "IMAGE_COUNT": IMAGE_COUNT,
        "VAL_PROPORTION": VAL_PROPORTION,
        "TRAIN_LENGTH": TRAIN_LENGTH,
        "VALID_LENGTH": VALID_LENGTH,
        "STEPS_PER_EPOCH": STEPS_PER_EPOCH,
        "VALIDATION_STEPS": VALIDATION_STEPS,
        "SEED": SEED,
        "REAL_LABEL_LOWER": REAL_LABEL_LOWER,
        "REAL_LABEL_UPPER": REAL_LABEL_UPPER,
        "BATCH_SIZE": BATCH_SIZE,
        "BUFFER_SIZE": BUFFER_SIZE,
        "IMAGE_SIZE": IMAGE_SIZE,
        "LAMBDA": LAMBDA,
        "EPOCHS": EPOCHS,
        "IS_TEST": IS_TEST,
        "TEST_SETTINGS": TEST_SETTINGS,
        "TEST_SIZE": TEST_SIZE,
        "PATCH_SIZE": PATCH_SIZE,
        "g_optimizer": "Adam",
        "g_learning_rate": G_LEARNING_RATE,
        "g_beta_1": G_BETA_1,
        "d_optimizer": "Adam",
        "d_learning_rate": D_LEARNING_RATE,
        "d_beta_1": D_BETA_1,
        "NEW_DATASET": NEW_DATASET,
    })

# %%
# wandb.finish()

# %% [markdown]
# # Prepare Dataset

# %%
def decode_sketch(sketch_path, image_shape):
    # takes a png file path and returns a tensor
    sketch = tf.io.read_file(sketch_path)
    sketch = tf.io.decode_png(sketch)
    sketch = tf.cast(sketch, tf.float32) / 255
    return tf.image.resize(sketch, image_shape, method='nearest')

def decode_image(image_path, image_shape):
    # takes a png file path and returns a tensor
    img = tf.io.read_file(image_path)
    img = tf.io.decode_png(img, channels=3) / 255 # [0,255] -> [0,1]
    img = img*2 - 1 # [0,1] -> [-1,1]  (range of tanh)
    img = tf.cast(img, tf.float32)
    return tf.image.resize(img, image_shape, method='nearest')

def process_path(fname, image_shape=[128,128]):
    # takes the sketch image path and returns tensors for the sketch and source image
    sketch_path = tf.strings.join([str(SKETCH_DIR), '\\', fname])
    image_path = tf.strings.join([str(IMAGES_DIR), '\\', fname])
    sketch = decode_sketch(sketch_path, image_shape)
    image = decode_image(image_path, image_shape)
    return sketch, image

def configure_for_performance(ds, subset=False):
    ds = ds.cache()
    if subset: # use 10% of the data
        ds = ds.shard(TEST_SIZE, 0)
    ds = ds.shuffle(buffer_size=BUFFER_SIZE)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.repeat()
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

def aug_fn(sketch, image):
    # both images should be transformed the same
    data = {"image":sketch, 'image1':image}
    aug_data = transforms(**data)
    aug_sketch = aug_data["image"]
    aug_image = aug_data["image1"]
    return aug_sketch, aug_image

def data_augmentation(sketch, image):
    # wrapper around augmentation function for tensorflow compatibility
    aug_sketch, aug_image = tf.numpy_function(func=aug_fn, inp=[sketch, image], Tout=[tf.float32, tf.float32])
    return aug_sketch, aug_image

# Instantiate augmentations - jitter, rotate, mirror
transforms = A.Compose([
    A.PadIfNeeded(min_height=IMAGE_SIZE[0]+20, min_width=IMAGE_SIZE[1]+20, border_mode=cv2.BORDER_CONSTANT, value=[1,1,1]),
    A.Rotate(limit=40, border_mode=cv2.BORDER_CONSTANT, value=[1,1,1]),
    A.RandomCrop(IMAGE_SIZE[0], IMAGE_SIZE[1]),
    A.HorizontalFlip()
    ], additional_targets={'image1':'image'})

# get a list of all the sketche paths
list_ds = tf.data.Dataset.from_tensor_slices(os.listdir(SKETCH_DIR))
list_ds = list_ds.shuffle(IMAGE_COUNT, seed=SEED, reshuffle_each_iteration=False)

# train / valid split
train_ds = list_ds.skip(VALID_LENGTH)
valid_ds = list_ds.take(VALID_LENGTH)

# process filepaths to images
train_ds = train_ds.map(functools.partial(process_path, image_shape=IMAGE_SIZE), num_parallel_calls=AUTOTUNE)
valid_ds = valid_ds.map(functools.partial(process_path, image_shape=IMAGE_SIZE), num_parallel_calls=AUTOTUNE)

# data augmentation on train set
train_ds = train_ds.map(data_augmentation)

# cache, shuffle, batch, repeat, prefetch
train_ds = configure_for_performance(train_ds, **TEST_SETTINGS)
valid_ds = configure_for_performance(valid_ds, **TEST_SETTINGS)

# %%
def show_batch(dataset, size=3, max_examples=8):
    """Print a batch of sketches and target frogs,
    for large batch sizes limit number to print"""
    
    # get a batch and prep the figure
    for sketch_batch, image_batch in dataset.take(1):
        # determine how many images to plot
        to_plot = min(sketch_batch.shape[0], max_examples)
        fig, axs = plt.subplots(2, to_plot, figsize=(size*to_plot, size*2))
        
        # print each img in the batch
        for i, (sketch, image) in enumerate(zip(sketch_batch, image_batch)):
            axs[0,i].imshow(sketch.numpy().squeeze(), cmap='gray')
            axs[1,i].imshow((image.numpy().squeeze()+1)/2)
            if i == to_plot-1:
                break

    # remove axis ticks
    for ax in matplotlib.cbook.flatten(axs):
        ax.set(xticks=[], yticks=[])

    # set titles
    axs[0,0].set_ylabel('Sketch')
    axs[1,0].set_ylabel('Source Image')

    # adjust styling and show
    fig.patch.set_facecolor('white')      
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    plt.show()
    plt.close()
    
show_batch(train_ds, max_examples=8)

# %% [markdown]
# # Define model

# %% [markdown]
# ## UNET Generator model

# %%
# UNET (generator)
def encoder_block(layer_in, n_filters, batchnorm=True):
    # weight initialization
    init = tf.initializers.RandomNormal(stddev=0.02)

    # add downsampling layer
    # if using batchnorm, then no bias needed
    g = layers.Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init, use_bias=not(batchnorm))(layer_in)

    # optional batchnorm
    if batchnorm:
        # always operate in training mode, even when used during inference
        g = layers.BatchNormalization()(g, training=True)

    # All ReLUs in the encoder are leaky, with slope 0.2
    g = layers.LeakyReLU(alpha=0.2)(g)
    return g

# define a decoder block
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
    # weight initialization
    init = tf.initializers.RandomNormal(stddev=0.02)

    # add upsampling layer
    g = layers.Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init, use_bias=False)(layer_in)

    # add batch norm always
    g = layers.BatchNormalization()(g, training=True)
    # optional dropout
    if dropout:
        g = layers.Dropout(0.5)(g, training=True)
    # merge with skip connection
    g = layers.Concatenate()([g, skip_in])
    # ReLUs in the decoder are not leaky
    g = layers.ReLU()(g)
    return g

def define_generator(sketch_shape=(128,128,1)):
    """Modified structure for 128x128 input, simply removed one layer from each side"""
    # weight initialization
    init = tf.initializers.RandomNormal(stddev=0.02)
    # image input
    in_image = layers.Input(shape=sketch_shape) # (batch_size, 128, 128, 1)

    # encoder model: C64-C128-C256-C512-C512-C512-C512
    # BatchNorm is not applied to the first C64 layer in the encoder
    e1 = encoder_block(in_image, 64, batchnorm=False) # (batch_size, 64, 64, 64)
    e2 = encoder_block(e1, 128)  # (batch_size, 32, 32, 128)
    e3 = encoder_block(e2, 256)  # (batch_size, 16, 16, 256)
    e4 = encoder_block(e3, 512)  # (batch_size,  8,  8, 512)
    e5 = encoder_block(e4, 512)  # (batch_size,  4,  4, 512)
    e6 = encoder_block(e5, 512)  # (batch_size,  2,  2, 512)

    # bottleneck, no batch norm, relu not leaky
    b = layers.Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e6)
    b = layers.ReLU()(b) # (batch_size, 1, 1, 512)

    # decoder model: CD512-CD1024-CD1024-C1024-C512-C256-C128
    # N.B. only first 3 use dropout
    d1 = decoder_block(b,  e6, 512, dropout=True)   # (batch_size,   2,   2, 1024) # doubles filters due to concat
    d2 = decoder_block(d1, e5, 512, dropout=True)   # (batch_size,   4,   4, 1024)
    d3 = decoder_block(d2, e4, 512, dropout=True)   # (batch_size,   8,   8, 1024)
    d4 = decoder_block(d3, e3, 256, dropout=False)  # (batch_size,  16,  16,  512)
    d5 = decoder_block(d4, e2, 128, dropout=False)  # (batch_size,  32,  32,  256)
    d6 = decoder_block(d5, e1,  64, dropout=False)  # (batch_size,  64,  64,  128)

    # output (batch_size, 128, 128, 3)
    g = layers.Conv2DTranspose(3, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d6)
    out_image = tf.keras.layers.Activation('tanh')(g)

    return Model(in_image, out_image)

# create the model
# model = define_generator()
# summarize the model
# model.summary()
# # plot the model
# plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# grab a sample image and mask to use throughout training
for sample_sketch_batch, sample_image_batch in train_ds.take(1):
  sample_sketch, sample_image = sample_sketch_batch[0], sample_image_batch[0]

fig, axs = plt.subplots(1,2) 
axs[0].imshow(sample_sketch, cmap='gray')
axs[1].imshow((sample_image+1)/2)
plt.show()

# %% [markdown]
# The training=True is intentional here since you want the batch statistics, while running the model on the test dataset. If you use training=False, you get the accumulated statistics learned from the training dataset (which you don't want).

# %% [markdown]
# ## PatchGAN Discriminator model

# %%
def viridis_extended():
    """Returns an extended viridis colormap for PatchGAN outputs
           x < -0.5  black
    -0.5 < x <  0    black -> viridis purple
     0   < x <  1    iridis
     1   < x <  1.5  viridis yellow -> white
     1.5 < x         white"""
  
    # get viridis and its reverse for convenience
    viridis = cm.get_cmap('viridis', 128)
    viridis_r = cm.get_cmap('viridis_r', 128)

    # left side: black -> viridis purple
    left_nodes = [0, 1]
    left_colors = [(0,0,0), viridis(0)[:3]]
    left = LinearSegmentedColormap.from_list("black_blue", list(zip(left_nodes, left_colors)))

    # right side viridis yellow -> white
    right_nodes = [0,1]
    right_colors = [viridis_r(0)[:3], (1,1,1)]
    right = LinearSegmentedColormap.from_list("black_blue", list(zip(right_nodes, right_colors)))

    viridis_extended = np.vstack((
        left(np.linspace(0, 1, 50)),
        viridis(np.linspace(0, 1, 100)),
        right(np.linspace(0, 1, 50))))

    return ListedColormap(viridis_extended)

# %%
# calculate the effective receptive field size
def receptive_field(output_size, kernel_size, stride_size):
    return (output_size - 1) * stride_size + kernel_size

def print_receptive_fields():
    # output layer 1x1 pixel with a 4x4 kernel and 1x1 stride
    rf = receptive_field(1, 4, 1)
    print(rf)

    # second last layer with 4x4 kernel and 1x1 stride
    rf = receptive_field(rf, 4, 1)
    print(rf)

    # 3 PatchGAN layers with 4x4 kernel and 2x2 stride
    rf = receptive_field(rf, 4, 2)
    print(rf)
    rf = receptive_field(rf, 4, 2)
    print(rf)
    rf = receptive_field(rf, 4, 2)
    print(rf)
    
# print_receptive_fields()

# %% [markdown]
# Running the example prints the size of the receptive field for each layer in the model from the output layer to the input layer.<br>
# We can see that each 1×1 pixel in the output layer maps to a 70×70 receptive field in the input layer.

# %%
# PatchGAN (discriminator)
def define_discriminator(sketch_shape=(128,128,1), image_shape=(128,128,3)):
    # weight initialization
    init = tf.initializers.RandomNormal(stddev=0.02)
    # source image input - same as input to generator
    in_src_image = layers.Input(shape=sketch_shape) # (batch_size, 128, 128, 1)
    # target image input - output of generator or a real image
    in_target_image = layers.Input(shape=image_shape) # (batch_size, 128, 128, 3)
    # concatenate images channel-wise (batch_size, 128, 128, 1+3=4)
    merged = layers.Concatenate()([in_src_image, in_target_image])

    # Ck denote a Convolution-BatchNorm-ReLU layer with k filters
    # model: C64-C128-C256-C512
    # C64 - BatchNorm is not applied to the first C64 layer (batch_size, 64, 64, 64)
    d = layers.Conv2D(64,  (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
    d = layers.LeakyReLU(alpha=0.2)(d) # All ReLUs are leaky, with slope 0.2
    # C128 (batch_size, 32, 32, 128)
    d = layers.Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
    d = layers.BatchNormalization()(d)
    d = layers.LeakyReLU(alpha=0.2)(d)
    # C256 (batch_size, 16, 16, 256)
    d = layers.Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
    d = layers.BatchNormalization()(d)
    d = layers.LeakyReLU(alpha=0.2)(d)
    # C512 (batch_size, 8, 8, 512)
    d = layers.Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
    d = layers.BatchNormalization()(d)
    d = layers.LeakyReLU(alpha=0.2)(d)
    # second last output layer - NB no strides (batch_size, 8, 8, 512)
    d = layers.Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
    d = layers.BatchNormalization()(d)
    d = layers.LeakyReLU(alpha=0.2)(d)
    # patch output (batch_size, 8, 8, 1)
    d = layers.Conv2D(1,   (4,4), padding='same', kernel_initializer=init)(d)
    # no activation if we want to use label smoothing
    # patch_out = layers.Activation('sigmoid')(d) # output [0,1]
    patch_out = d

    # define model 
    return Model([in_src_image, in_target_image], patch_out)

# create the model
# test_disc = define_discriminator()
# # summarize the model
# model.summary()
# # plot the model
# plot_model(model, to_file='discriminator_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# We can see that the model output will be an activation map with the size 8x8 pixels or activations and a single channel, with each value in the map corresponding to a 70×70 pixel patch of the input 128x128 image.

# %% [markdown]
# ## Losses

# %%
def pix2pix_generator_loss(y_pred, y_target, out_img, target_img, LAMBDA=100):
    """
    loss=['binary_crossentropy', 'mae']
    loss_weights=[1, 100]
    The Pix2Pix generator uses a composite of Adversarial Loss (BCE) and L1 Loss (Pixel Distance Loss)

    The adversarial loss influences whether the generator
    model can output images that are plausible in the target domain.
    This is calculated from the output of the discriminator.
    Non-saturating GAN Loss:
        maximize the probability of images being predicted as real.
    Hence y_target is an array of ones.
    
    The L1 loss regularizes the generator model to output images
    that are a plausible translation of the source image.
    This is calculated from the output of the generator.
    """   
    # binary cross entropy - patches
    gan_loss = generator_loss_object(y_target, y_pred)

    # Pixel distance loss (L1)
    l1_loss = tf.reduce_mean(tf.abs(target_img - out_img))

    total_gen_loss = gan_loss + (LAMBDA * l1_loss)

    return total_gen_loss, gan_loss, l1_loss

def pix2pix_discriminator_loss(d_real_pred, d_real_target, d_fake_pred, d_fake_target):
    """Combine the discriminator losses from both the real and fake images"""
    
    real_loss = discriminator_loss_object(d_real_target, d_real_pred)
    fake_loss = discriminator_loss_object(d_fake_target, d_fake_pred)
    
    return real_loss + fake_loss

# %% [markdown]
# ## Combined GAN Model

# %%
class Pix2Pix(tf.keras.Model):
    """
    Inspired by this twitter post from the creator of keras
    https://twitter.com/fchollet/status/1250622989541838848/photo/1
    and the pix2pix tensorflow tutorial
    https://www.tensorflow.org/tutorials/generative/pix2pix

    patch_size is the size of the output of the PatchGAN discriminator
    """
    def __init__(self, generator, discriminator, patch_size=8, real_label_lower=0.8, real_label_upper=1.2):
        super(Pix2Pix, self).__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.patch_size = patch_size
        self.real_label_lower = real_label_lower
        self.real_label_upper = real_label_upper
        
    def compile(self, g_optimizer, d_optimizer, g_loss_fn, d_loss_fn):
        super(Pix2Pix, self).compile()
        self.g_optimizer = g_optimizer # Adam(lr=0.0002, beta_1=0.5)
        self.d_optimizer = d_optimizer # Adam(lr=0.0002, beta_1=0.5)
        self.g_loss_fn = g_loss_fn # loss=['binary_crossentropy', 'mae'], loss_weights=[1, 100]
        self.d_loss_fn = d_loss_fn # bce, loss_weights=[0.5]

    def call(self, data, training=False):
        # unpack data into normal (A) / shiny (B)
        # X_realA, X_realB = data
        gen_out = self.generator(data, training=training)
        dis_out = self.discriminator([data, gen_out], training=training)

        return dis_out, gen_out

    def show_single_prediction(self, input_img, target_img=False, wandb_title=False, show_plot=False, patch_cmap='viridis', patch_vmin=-0.5, patch_vmax=1.5):
        dis_out, gen_out = self.call(input_img)
        
        if isinstance(target_img, tf.Tensor):
            titles = ['Input Sketch', 'Target Image', 'Predicted Image', 'PatchGAN Output']
            display_list = [input_img, target_img, gen_out, dis_out]
            fig, axs = plt.subplots(1, 4, figsize=(20, 5))
        else:
            titles = ['Input Sketch', 'Predicted Image', 'PatchGAN Output']
            display_list = [input_img, gen_out, dis_out]
            fig, axs = plt.subplots(1, 3, figsize=(15, 5))

        for i, (ax, title, img) in enumerate(zip(axs, titles, display_list)):
            
            if title in ['Input Sketch', 'Target Image', 'Predicted Image']:
                img = img[0,...]
                img = tf.keras.preprocessing.image.array_to_img(img)
                ax.imshow(img, cmap='gray')
            elif title == 'PatchGAN Output':
                img = img[0,:,:,0].numpy()
                im = ax.imshow(img, vmin=patch_vmin, vmax=patch_vmax, cmap=patch_cmap)
            
            # axis formatting
            ax.set_title(title)
            ax.axis('off')

        # figure formatting
        cb = fig.colorbar(im, ax=axs[-1], extend='both')
        plt.subplots_adjust(wspace=0.05, hspace=0.05)

        if wandb_title:
            wandb.log({wandb_title: plt})

        if show_plot:
            plt.show()
        plt.close()

    def train_step(self, data):
        """Chollet's approach trains the discriminator, then generates new images and trains the generator
        Each time overwriting the GradientTape and predictions.
        
        Meanwhile this approach (pix2pix tf tutorial) creates a gen_tape and disc_tape simultaneously.
        Thus the gradients for training the gen and disc must both be available at the same time.
        I suspect that this approach will require more VRAM,
        but since it only has a single forward pass through the generator it may save time overall"""
        
        # unpack data into sketches (input) and images (target)
        input_batch, target_batch = data
        batch_size = tf.shape(input_batch)[0]
        
        # create patchgan labels
        labels_real = tf.ones((batch_size, self.patch_size, self.patch_size, 1))
        labels_fake = tf.zeros((batch_size, self.patch_size, self.patch_size, 1))
        
        # create smoothed patchgan -labels for reals
        labels_real_smoothed = tf.random.uniform(
            shape=(batch_size, self.patch_size, self.patch_size, 1),
            minval=self.real_label_lower,
            maxval=self.real_label_upper)
        
        # complete the forward pass and calculate the losses
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            # generate fake images once
            gen_output = self.generator(input_batch, training=True)
            
            # predict on reals and fakes separately due to Batchnorm layers
            disc_real_pred = self.discriminator([input_batch, target_batch], training=True)
            disc_fake_pred = self.discriminator([input_batch, gen_output], training=True)
            
            # y_target is an array of ones to maximise the probability of generated images
            # being predicted as real - non-saturating GAN loss
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss_fn(
                y_pred=disc_fake_pred, y_target=labels_real,
                out_img=gen_output,  target_img=target_batch)
            
            # calculate the discriminator loss, combining reals and fakes
            # with one-sided label smoothing on the reals.
            disc_loss = self.d_loss_fn(
                d_real_pred=disc_real_pred, d_real_target=labels_real_smoothed,
                d_fake_pred=disc_fake_pred, d_fake_target=labels_fake)
        
        # calculate gradients and update weights
        gen_gradients = gen_tape.gradient(gen_total_loss, self.generator.trainable_weights)
        disc_gradients = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)
        
        self.g_optimizer.apply_gradients(zip(gen_gradients, self.generator.trainable_weights))
        self.d_optimizer.apply_gradients(zip(disc_gradients, self.discriminator.trainable_weights))

        return {
            'd_loss': disc_loss,
            'gen_total_loss': gen_total_loss,
            'gen_gan_loss': gen_gan_loss,
            'gen_l1_loss': gen_l1_loss
            }

# %% [markdown]
# First run used a label smoothing on both sides in both the discriminator and generator. Smoothing was a gaussian (mean=0, std=1) * 0.05. Doing so meant that the positive class could have target value above or below 1, not just above. There is also the possiblity of being very far from 1 or 0. By comparison, Chollet uses a uniform distribution*0.05 so target labels are [0, 0.05] [1, 1.05] only in the discriminator.
#
# Now we will use: uniform smoothing on just the positive label (one sided) in the discriminator
#
# https://datascience.stackexchange.com/questions/28764/one-sided-label-smoothing-in-gans
#
# One sided Label Smoothing would smooth the positive target only. Only when training the Discriminator. When training the Generator we do not smooth the labels. This is because label smoothing is a form of regularisation to slow down the discriminator.
#
# Should I use the same X_realA data fir training the discriminato and the generator? Or do I need to use half a batch on each? Chollet's example uses a different inpuit to G wehn training G and D. The tensorflow tutorial only generates images once.

# %% [markdown]
# <code>
# generator
# tanh - True
# from_logits = True
#
# Discriminator
# sigmoid - off
# from_logits=True
# Required for label smoothing
# </code>

# %% [markdown]
# # Build Model

# %%
generator = define_generator()
discriminator = define_discriminator()
model = Pix2Pix(generator, discriminator,
                patch_size=PATCH_SIZE,
                real_label_lower=REAL_LABEL_LOWER,
                real_label_upper=REAL_LABEL_UPPER)

# generator loss has tanh activation [-1,1]
# generator_loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
generator_loss_object = tf.keras.losses.MeanSquaredError()
generator_loss = functools.partial(pix2pix_generator_loss, LAMBDA=LAMBDA)

# discriminator loss has no activation
# discriminator_loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=False) # is this still correct now, previously True?
discriminator_loss_object = tf.keras.losses.MeanSquaredError()
discriminator_loss = pix2pix_discriminator_loss

model.compile(
    tf.keras.optimizers.Adam(lr=G_LEARNING_RATE, beta_1=G_BETA_1), # g_optimizer
    tf.keras.optimizers.Adam(lr=D_LEARNING_RATE, beta_1=D_BETA_1), # d_optimizer
    generator_loss, discriminator_loss)

# check outputs
cmap = viridis_extended()
model.show_single_prediction(sample_sketch[tf.newaxis, ...], sample_image[tf.newaxis, ...], show_plot=True, patch_cmap=cmap)

# %% [markdown]
# ## Callbacks

# %%
# observe improvement while training
class DisplayCallback(tf.keras.callbacks.Callback):
    
    def __init__(self, steps_per_epoch, continue_training=False, patch_cmap='viridis'):
        """
        During the first epoch we want to log more frequently.
        If we continue training from the nth epoch we don't want 
        these extra logs on epoch n.
        
        During the first epoch, logs are madfe evenly on a logarithmic scale."""
        
        self.is_first_epoch = not(continue_training)
        self.batches_to_log = np.geomspace(1, steps_per_epoch, 10).astype(int) - 1
        self.patch_cmap = patch_cmap
        
        
    def on_epoch_end(self, epoch, logs=None):
        model.show_single_prediction(
            sample_sketch[tf.newaxis, ...],
            sample_image[tf.newaxis, ...],
            wandb_title=f'Training example',
            patch_cmap=self.patch_cmap)
        
        # plot validation example
        for x_batch, y_batch in valid_ds.take(1):
            val_sketch, val_image = x_batch[0], y_batch[0]
            model.show_single_prediction(
                val_sketch[tf.newaxis, ...],
                val_image[tf.newaxis, ...],
                wandb_title=f'Validation example',
                patch_cmap=self.patch_cmap)

    def on_train_begin(self, epoch, logs=None):
        # only at the very start of training.
        # Not if we are continuing training
        if self.is_first_epoch:
            model.show_single_prediction(
                sample_sketch[tf.newaxis, ...],
                sample_image[tf.newaxis, ...],
                wandb_title='Training example before training',
                patch_cmap=self.patch_cmap)
    
    def on_train_batch_end(self, batch, logs=None):
        # we only want to log during the first epoch
        if self.is_first_epoch:
            # only log specific batches, spaced on a log curve
            if batch in self.batches_to_log:
                
                model.show_single_prediction(
                    sample_sketch[tf.newaxis, ...],
                    sample_image[tf.newaxis, ...],
                    wandb_title=f'Training example Epoch 0',
                    patch_cmap=self.patch_cmap)
                
                # plot validation example
                for x_batch, y_batch in valid_ds.take(1):
                    val_sketch, val_image = x_batch[0], y_batch[0]
                    model.show_single_prediction(
                        val_sketch[tf.newaxis, ...],
                        val_image[tf.newaxis, ...],
                        wandb_title=f'Validation example Epoch 0',
                        patch_cmap=self.patch_cmap)
                
                # after saving examples of the last batch in epoch one
                # set is_first_batch to false
                if batch == self.batches_to_log[-1]:
                    self.is_first_epoch = False

# %% [markdown]
# # Training

# %%
if USE_WANDB:
    callbacks = [
        DisplayCallback(steps_per_epoch=STEPS_PER_EPOCH, patch_cmap=cmap),
        WandbCallback(),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=str(MODELS_DIR / RUN_NAME) +' {epoch:03d}E',
            verbose=1, 
            save_weights_only=False,
            save_freq= int(50 * STEPS_PER_EPOCH)) # save every 50 epochs
        ]
else:
    callbacks = []

# build the model with correct shapes
for sketch_batch, image_batch in train_ds.take(1):
    model.predict(sketch_batch)

history = model.fit(
    train_ds,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_steps=VALIDATION_STEPS,
    validation_data=valid_ds,
    # verbose=0,
    callbacks=callbacks)
# Out:
# Epoch 1/300
#   6/109 [>.............................] - ETA: 1:51 - d_loss: 6.2432 - gen_total_loss: 78.7364 - gen_gan_loss: 2.7245 - gen_l1_loss: 0.7601WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1449s vs `on_train_batch_end` time: 0.7826s). Check your callbacks.
# 109/109 [==============================] - 51s 404ms/step - d_loss: 1.8802 - gen_total_loss: 33.3169 - gen_gan_loss: 1.5161 - gen_l1_loss: 0.3180
# Epoch 2/300
# 109/109 [==============================] - 37s 327ms/step - d_loss: 0.3704 - gen_total_loss: 17.1597 - gen_gan_loss: 0.4860 - gen_l1_loss: 0.1667
# Epoch 3/300
# 109/109 [==============================] - 37s 342ms/step - d_loss: 0.2408 - gen_total_loss: 16.4310 - gen_gan_loss: 0.7102 - gen_l1_loss: 0.1572
# Epoch 4/300
# 109/109 [==============================] - 37s 337ms/step - d_loss: 0.1811 - gen_total_loss: 16.0389 - gen_gan_loss: 0.7860 - gen_l1_loss: 0.1525
# Epoch 5/300
# 109/109 [==============================] - 37s 338ms/step - d_loss: 0.2230 - gen_total_loss: 15.5795 - gen_gan_loss: 0.7703 - gen_l1_loss: 0.1481
# Epoch 6/300
# 109/109 [==============================] - 37s 338ms/step - d_loss: 0.1732 - gen_total_loss: 15.2589 - gen_gan_loss: 0.8252 - gen_l1_loss: 0.1443
# Epoch 7/300
# 109/109 [==============================] - 37s 336ms/step - d_loss: 0.2232 - gen_total_loss: 14.5453 - gen_gan_loss: 0.7429 - gen_l1_loss: 0.1380
# Epoch 8/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2414 - gen_total_loss: 14.1293 - gen_gan_loss: 0.7347 - gen_l1_loss: 0.1339
# Epoch 9/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2253 - gen_total_loss: 13.8232 - gen_gan_loss: 0.7397 - gen_l1_loss: 0.1308
# Epoch 10/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2016 - gen_total_loss: 13.6287 - gen_gan_loss: 0.7709 - gen_l1_loss: 0.1286
# Epoch 11/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2108 - gen_total_loss: 13.2809 - gen_gan_loss: 0.7679 - gen_l1_loss: 0.1251
# Epoch 12/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2012 - gen_total_loss: 13.0330 - gen_gan_loss: 0.7735 - gen_l1_loss: 0.1226
# Epoch 13/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2175 - gen_total_loss: 12.8271 - gen_gan_loss: 0.7474 - gen_l1_loss: 0.1208
# Epoch 14/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2341 - gen_total_loss: 12.4914 - gen_gan_loss: 0.7278 - gen_l1_loss: 0.1176
# Epoch 15/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2512 - gen_total_loss: 12.3158 - gen_gan_loss: 0.6891 - gen_l1_loss: 0.1163
# Epoch 16/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2382 - gen_total_loss: 12.1593 - gen_gan_loss: 0.7159 - gen_l1_loss: 0.1144
# Epoch 17/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2451 - gen_total_loss: 11.9922 - gen_gan_loss: 0.7274 - gen_l1_loss: 0.1126
# Epoch 18/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2418 - gen_total_loss: 11.7242 - gen_gan_loss: 0.7141 - gen_l1_loss: 0.1101
# Epoch 19/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2465 - gen_total_loss: 11.5967 - gen_gan_loss: 0.7210 - gen_l1_loss: 0.1088
# Epoch 20/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2457 - gen_total_loss: 11.4719 - gen_gan_loss: 0.6942 - gen_l1_loss: 0.1078
# Epoch 21/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2424 - gen_total_loss: 11.2879 - gen_gan_loss: 0.7014 - gen_l1_loss: 0.1059
# Epoch 22/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2536 - gen_total_loss: 11.2692 - gen_gan_loss: 0.6868 - gen_l1_loss: 0.1058
# Epoch 23/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2746 - gen_total_loss: 11.0570 - gen_gan_loss: 0.7157 - gen_l1_loss: 0.1034
# Epoch 24/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2448 - gen_total_loss: 10.9299 - gen_gan_loss: 0.6863 - gen_l1_loss: 0.1024
# Epoch 25/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2599 - gen_total_loss: 10.8544 - gen_gan_loss: 0.6745 - gen_l1_loss: 0.1018
# Epoch 26/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2624 - gen_total_loss: 10.7552 - gen_gan_loss: 0.6519 - gen_l1_loss: 0.1010
# Epoch 27/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2793 - gen_total_loss: 10.6461 - gen_gan_loss: 0.6564 - gen_l1_loss: 0.0999
# Epoch 28/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2787 - gen_total_loss: 10.4318 - gen_gan_loss: 0.6559 - gen_l1_loss: 0.0978
# Epoch 29/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2858 - gen_total_loss: 10.3861 - gen_gan_loss: 0.6545 - gen_l1_loss: 0.0973
# Epoch 30/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2776 - gen_total_loss: 10.3372 - gen_gan_loss: 0.6367 - gen_l1_loss: 0.0970
# Epoch 31/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3037 - gen_total_loss: 10.2627 - gen_gan_loss: 0.6035 - gen_l1_loss: 0.0966
# Epoch 32/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2958 - gen_total_loss: 10.1859 - gen_gan_loss: 0.6224 - gen_l1_loss: 0.0956
# Epoch 33/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3240 - gen_total_loss: 9.9993 - gen_gan_loss: 0.6011 - gen_l1_loss: 0.0940
# Epoch 34/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2831 - gen_total_loss: 9.9750 - gen_gan_loss: 0.6174 - gen_l1_loss: 0.0936
# Epoch 35/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2945 - gen_total_loss: 9.8207 - gen_gan_loss: 0.6126 - gen_l1_loss: 0.0921
# Epoch 36/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2960 - gen_total_loss: 9.8309 - gen_gan_loss: 0.5921 - gen_l1_loss: 0.0924
# Epoch 37/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3070 - gen_total_loss: 9.7072 - gen_gan_loss: 0.6000 - gen_l1_loss: 0.0911
# Epoch 38/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3098 - gen_total_loss: 9.7061 - gen_gan_loss: 0.5798 - gen_l1_loss: 0.0913
# Epoch 39/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3047 - gen_total_loss: 9.6076 - gen_gan_loss: 0.5649 - gen_l1_loss: 0.0904
# Epoch 40/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3202 - gen_total_loss: 9.5603 - gen_gan_loss: 0.5893 - gen_l1_loss: 0.0897
# Epoch 41/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3197 - gen_total_loss: 9.4329 - gen_gan_loss: 0.5716 - gen_l1_loss: 0.0886
# Epoch 42/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3273 - gen_total_loss: 9.4238 - gen_gan_loss: 0.5450 - gen_l1_loss: 0.0888
# Epoch 43/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3372 - gen_total_loss: 9.3540 - gen_gan_loss: 0.5442 - gen_l1_loss: 0.0881
# Epoch 44/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3304 - gen_total_loss: 9.2094 - gen_gan_loss: 0.5708 - gen_l1_loss: 0.0864
# Epoch 45/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3195 - gen_total_loss: 9.1639 - gen_gan_loss: 0.5571 - gen_l1_loss: 0.0861
# Epoch 46/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3357 - gen_total_loss: 9.1293 - gen_gan_loss: 0.5497 - gen_l1_loss: 0.0858
# Epoch 47/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3383 - gen_total_loss: 9.0714 - gen_gan_loss: 0.5578 - gen_l1_loss: 0.0851
# Epoch 48/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3252 - gen_total_loss: 9.0209 - gen_gan_loss: 0.5165 - gen_l1_loss: 0.0850
# Epoch 49/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3312 - gen_total_loss: 9.0474 - gen_gan_loss: 0.5397 - gen_l1_loss: 0.0851
# Epoch 50/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.3409 - gen_total_loss: 8.9171 - gen_gan_loss: 0.5435 - gen_l1_loss: 0.0837
# Epoch 00050: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 050E
# 109/109 [==============================] - 38s 349ms/step - d_loss: 0.3397 - gen_total_loss: 8.9191 - gen_gan_loss: 0.5434 - gen_l1_loss: 0.0838
# Epoch 51/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3293 - gen_total_loss: 8.8408 - gen_gan_loss: 0.5542 - gen_l1_loss: 0.0829
# Epoch 52/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3208 - gen_total_loss: 8.7670 - gen_gan_loss: 0.5605 - gen_l1_loss: 0.0821
# Epoch 53/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3388 - gen_total_loss: 8.7628 - gen_gan_loss: 0.5399 - gen_l1_loss: 0.0822
# Epoch 54/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3246 - gen_total_loss: 8.7613 - gen_gan_loss: 0.5344 - gen_l1_loss: 0.0823
# Epoch 55/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3220 - gen_total_loss: 8.7748 - gen_gan_loss: 0.5435 - gen_l1_loss: 0.0823
# Epoch 56/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3258 - gen_total_loss: 8.7069 - gen_gan_loss: 0.5466 - gen_l1_loss: 0.0816
# Epoch 57/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3214 - gen_total_loss: 8.6458 - gen_gan_loss: 0.5548 - gen_l1_loss: 0.0809
# Epoch 58/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3249 - gen_total_loss: 8.5767 - gen_gan_loss: 0.5612 - gen_l1_loss: 0.0802
# Epoch 59/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3479 - gen_total_loss: 8.5312 - gen_gan_loss: 0.5692 - gen_l1_loss: 0.0796
# Epoch 60/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3291 - gen_total_loss: 8.4702 - gen_gan_loss: 0.5622 - gen_l1_loss: 0.0791
# Epoch 61/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2966 - gen_total_loss: 8.4170 - gen_gan_loss: 0.5400 - gen_l1_loss: 0.0788
# Epoch 62/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3209 - gen_total_loss: 8.4283 - gen_gan_loss: 0.5497 - gen_l1_loss: 0.0788
# Epoch 63/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3338 - gen_total_loss: 8.3489 - gen_gan_loss: 0.5585 - gen_l1_loss: 0.0779
# Epoch 64/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3367 - gen_total_loss: 8.3893 - gen_gan_loss: 0.5267 - gen_l1_loss: 0.0786
# Epoch 65/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3976 - gen_total_loss: 8.2114 - gen_gan_loss: 0.5513 - gen_l1_loss: 0.0766
# Epoch 66/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3061 - gen_total_loss: 7.9907 - gen_gan_loss: 0.4993 - gen_l1_loss: 0.0749
# Epoch 67/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3143 - gen_total_loss: 8.2459 - gen_gan_loss: 0.5381 - gen_l1_loss: 0.0771
# Epoch 68/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3529 - gen_total_loss: 8.2631 - gen_gan_loss: 0.5384 - gen_l1_loss: 0.0772
# Epoch 69/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3139 - gen_total_loss: 8.2126 - gen_gan_loss: 0.5280 - gen_l1_loss: 0.0768
# Epoch 70/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3234 - gen_total_loss: 8.1639 - gen_gan_loss: 0.5400 - gen_l1_loss: 0.0762
# Epoch 71/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3482 - gen_total_loss: 8.0391 - gen_gan_loss: 0.5375 - gen_l1_loss: 0.0750
# Epoch 72/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3384 - gen_total_loss: 8.0418 - gen_gan_loss: 0.5374 - gen_l1_loss: 0.0750
# Epoch 73/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3081 - gen_total_loss: 8.0983 - gen_gan_loss: 0.5370 - gen_l1_loss: 0.0756
# Epoch 74/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3258 - gen_total_loss: 8.0782 - gen_gan_loss: 0.5611 - gen_l1_loss: 0.0752
# Epoch 75/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3099 - gen_total_loss: 8.0125 - gen_gan_loss: 0.5504 - gen_l1_loss: 0.0746
# Epoch 76/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3193 - gen_total_loss: 7.9492 - gen_gan_loss: 0.5543 - gen_l1_loss: 0.0739
# Epoch 77/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3092 - gen_total_loss: 7.9405 - gen_gan_loss: 0.5540 - gen_l1_loss: 0.0739
# Epoch 78/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.4005 - gen_total_loss: 7.8842 - gen_gan_loss: 0.5722 - gen_l1_loss: 0.0731
# Epoch 79/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3387 - gen_total_loss: 7.8293 - gen_gan_loss: 0.5349 - gen_l1_loss: 0.0729
# Epoch 80/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3193 - gen_total_loss: 7.6962 - gen_gan_loss: 0.5274 - gen_l1_loss: 0.0717
# Epoch 81/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2975 - gen_total_loss: 7.8787 - gen_gan_loss: 0.5687 - gen_l1_loss: 0.0731
# Epoch 82/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2867 - gen_total_loss: 7.8738 - gen_gan_loss: 0.5509 - gen_l1_loss: 0.0732
# Epoch 83/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3118 - gen_total_loss: 7.7979 - gen_gan_loss: 0.5639 - gen_l1_loss: 0.0723
# Epoch 84/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3092 - gen_total_loss: 7.8265 - gen_gan_loss: 0.5612 - gen_l1_loss: 0.0727
# Epoch 85/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3125 - gen_total_loss: 7.7800 - gen_gan_loss: 0.5440 - gen_l1_loss: 0.0724
# Epoch 86/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3038 - gen_total_loss: 7.8325 - gen_gan_loss: 0.5674 - gen_l1_loss: 0.0727
# Epoch 87/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.3269 - gen_total_loss: 7.7447 - gen_gan_loss: 0.5486 - gen_l1_loss: 0.0720
# Epoch 88/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.3064 - gen_total_loss: 7.7374 - gen_gan_loss: 0.5336 - gen_l1_loss: 0.0720
# Epoch 89/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3354 - gen_total_loss: 7.7320 - gen_gan_loss: 0.5419 - gen_l1_loss: 0.0719
# Epoch 90/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3077 - gen_total_loss: 7.6763 - gen_gan_loss: 0.5325 - gen_l1_loss: 0.0714
# Epoch 91/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3229 - gen_total_loss: 7.6707 - gen_gan_loss: 0.5392 - gen_l1_loss: 0.0713
# Epoch 92/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3234 - gen_total_loss: 7.6342 - gen_gan_loss: 0.5448 - gen_l1_loss: 0.0709
# Epoch 93/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3362 - gen_total_loss: 7.5795 - gen_gan_loss: 0.5311 - gen_l1_loss: 0.0705
# Epoch 94/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3250 - gen_total_loss: 7.5389 - gen_gan_loss: 0.5217 - gen_l1_loss: 0.0702
# Epoch 95/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3320 - gen_total_loss: 7.5873 - gen_gan_loss: 0.5375 - gen_l1_loss: 0.0705
# Epoch 96/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3129 - gen_total_loss: 7.5680 - gen_gan_loss: 0.5227 - gen_l1_loss: 0.0705
# Epoch 97/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3195 - gen_total_loss: 7.5611 - gen_gan_loss: 0.5371 - gen_l1_loss: 0.0702
# Epoch 98/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3243 - gen_total_loss: 7.5317 - gen_gan_loss: 0.5319 - gen_l1_loss: 0.0700
# Epoch 99/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3286 - gen_total_loss: 7.5058 - gen_gan_loss: 0.5370 - gen_l1_loss: 0.0697
# Epoch 100/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.3132 - gen_total_loss: 7.4650 - gen_gan_loss: 0.5339 - gen_l1_loss: 0.0693
# Epoch 00100: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 100E
# 109/109 [==============================] - 38s 347ms/step - d_loss: 0.3141 - gen_total_loss: 7.4604 - gen_gan_loss: 0.5305 - gen_l1_loss: 0.0693
# Epoch 101/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3475 - gen_total_loss: 7.4453 - gen_gan_loss: 0.5421 - gen_l1_loss: 0.0690
# Epoch 102/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3155 - gen_total_loss: 7.4314 - gen_gan_loss: 0.5125 - gen_l1_loss: 0.0692
# Epoch 103/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3202 - gen_total_loss: 7.4244 - gen_gan_loss: 0.5342 - gen_l1_loss: 0.0689
# Epoch 104/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3365 - gen_total_loss: 7.3840 - gen_gan_loss: 0.5277 - gen_l1_loss: 0.0686
# Epoch 105/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3221 - gen_total_loss: 7.4034 - gen_gan_loss: 0.5353 - gen_l1_loss: 0.0687
# Epoch 106/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3304 - gen_total_loss: 7.3664 - gen_gan_loss: 0.5369 - gen_l1_loss: 0.0683
# Epoch 107/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3131 - gen_total_loss: 7.3850 - gen_gan_loss: 0.5392 - gen_l1_loss: 0.0685
# Epoch 108/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3394 - gen_total_loss: 7.3335 - gen_gan_loss: 0.5260 - gen_l1_loss: 0.0681
# Epoch 109/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3144 - gen_total_loss: 7.3266 - gen_gan_loss: 0.5318 - gen_l1_loss: 0.0679
# Epoch 110/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3155 - gen_total_loss: 7.3492 - gen_gan_loss: 0.5244 - gen_l1_loss: 0.0682
# Epoch 111/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3247 - gen_total_loss: 7.3407 - gen_gan_loss: 0.5353 - gen_l1_loss: 0.0681
# Epoch 112/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3087 - gen_total_loss: 7.3089 - gen_gan_loss: 0.5366 - gen_l1_loss: 0.0677
# Epoch 113/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3310 - gen_total_loss: 7.2911 - gen_gan_loss: 0.5556 - gen_l1_loss: 0.0674
# Epoch 114/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4346 - gen_total_loss: 7.0759 - gen_gan_loss: 0.5419 - gen_l1_loss: 0.0653
# Epoch 115/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3026 - gen_total_loss: 7.1481 - gen_gan_loss: 0.4891 - gen_l1_loss: 0.0666
# Epoch 116/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3633 - gen_total_loss: 7.0154 - gen_gan_loss: 0.4877 - gen_l1_loss: 0.0653
# Epoch 117/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3119 - gen_total_loss: 7.1599 - gen_gan_loss: 0.5146 - gen_l1_loss: 0.0665
# Epoch 118/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3058 - gen_total_loss: 7.1959 - gen_gan_loss: 0.5317 - gen_l1_loss: 0.0666
# Epoch 119/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3353 - gen_total_loss: 7.1827 - gen_gan_loss: 0.5207 - gen_l1_loss: 0.0666
# Epoch 120/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3157 - gen_total_loss: 7.1861 - gen_gan_loss: 0.5311 - gen_l1_loss: 0.0665
# Epoch 121/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3286 - gen_total_loss: 7.0866 - gen_gan_loss: 0.5326 - gen_l1_loss: 0.0655
# Epoch 122/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.3059 - gen_total_loss: 7.1318 - gen_gan_loss: 0.5246 - gen_l1_loss: 0.0661
# Epoch 123/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.3190 - gen_total_loss: 7.1007 - gen_gan_loss: 0.5233 - gen_l1_loss: 0.0658
# Epoch 124/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3011 - gen_total_loss: 7.1329 - gen_gan_loss: 0.5372 - gen_l1_loss: 0.0660
# Epoch 125/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3166 - gen_total_loss: 7.1159 - gen_gan_loss: 0.5283 - gen_l1_loss: 0.0659
# Epoch 126/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3278 - gen_total_loss: 7.0737 - gen_gan_loss: 0.5391 - gen_l1_loss: 0.0653
# Epoch 127/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3090 - gen_total_loss: 7.0795 - gen_gan_loss: 0.5421 - gen_l1_loss: 0.0654
# Epoch 128/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4316 - gen_total_loss: 6.9051 - gen_gan_loss: 0.5276 - gen_l1_loss: 0.0638
# Epoch 129/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3047 - gen_total_loss: 7.0231 - gen_gan_loss: 0.5200 - gen_l1_loss: 0.0650
# Epoch 130/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2996 - gen_total_loss: 7.0179 - gen_gan_loss: 0.5399 - gen_l1_loss: 0.0648
# Epoch 131/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2881 - gen_total_loss: 7.0519 - gen_gan_loss: 0.5575 - gen_l1_loss: 0.0649
# Epoch 132/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.3166 - gen_total_loss: 7.0198 - gen_gan_loss: 0.5460 - gen_l1_loss: 0.0647
# Epoch 133/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2846 - gen_total_loss: 7.0498 - gen_gan_loss: 0.5609 - gen_l1_loss: 0.0649
# Epoch 134/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2807 - gen_total_loss: 7.1008 - gen_gan_loss: 0.5520 - gen_l1_loss: 0.0655
# Epoch 135/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3184 - gen_total_loss: 7.0175 - gen_gan_loss: 0.5649 - gen_l1_loss: 0.0645
# Epoch 136/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2901 - gen_total_loss: 6.9914 - gen_gan_loss: 0.5362 - gen_l1_loss: 0.0646
# Epoch 137/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3082 - gen_total_loss: 6.9918 - gen_gan_loss: 0.5550 - gen_l1_loss: 0.0644
# Epoch 138/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3057 - gen_total_loss: 6.9961 - gen_gan_loss: 0.5478 - gen_l1_loss: 0.0645
# Epoch 139/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3233 - gen_total_loss: 6.9844 - gen_gan_loss: 0.5399 - gen_l1_loss: 0.0644
# Epoch 140/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3030 - gen_total_loss: 6.9930 - gen_gan_loss: 0.5413 - gen_l1_loss: 0.0645
# Epoch 141/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3197 - gen_total_loss: 6.9409 - gen_gan_loss: 0.5398 - gen_l1_loss: 0.0640
# Epoch 142/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3015 - gen_total_loss: 6.9431 - gen_gan_loss: 0.5385 - gen_l1_loss: 0.0640
# Epoch 143/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3056 - gen_total_loss: 6.9565 - gen_gan_loss: 0.5404 - gen_l1_loss: 0.0642
# Epoch 144/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2985 - gen_total_loss: 6.9603 - gen_gan_loss: 0.5428 - gen_l1_loss: 0.0642
# Epoch 145/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3287 - gen_total_loss: 6.9587 - gen_gan_loss: 0.5497 - gen_l1_loss: 0.0641
# Epoch 146/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3201 - gen_total_loss: 6.8854 - gen_gan_loss: 0.5388 - gen_l1_loss: 0.0635
# Epoch 147/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4453 - gen_total_loss: 6.7943 - gen_gan_loss: 0.5517 - gen_l1_loss: 0.0624
# Epoch 148/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3427 - gen_total_loss: 6.6010 - gen_gan_loss: 0.4448 - gen_l1_loss: 0.0616
# Epoch 149/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.3155 - gen_total_loss: 6.8075 - gen_gan_loss: 0.5239 - gen_l1_loss: 0.0628
# Epoch 150/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.3093 - gen_total_loss: 6.7953 - gen_gan_loss: 0.5370 - gen_l1_loss: 0.0626
# Epoch 00150: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 150E
# 109/109 [==============================] - 38s 347ms/step - d_loss: 0.3081 - gen_total_loss: 6.7963 - gen_gan_loss: 0.5373 - gen_l1_loss: 0.0626
# Epoch 151/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2933 - gen_total_loss: 6.8729 - gen_gan_loss: 0.5543 - gen_l1_loss: 0.0632
# Epoch 152/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2797 - gen_total_loss: 6.9069 - gen_gan_loss: 0.5474 - gen_l1_loss: 0.0636
# Epoch 153/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3191 - gen_total_loss: 6.8354 - gen_gan_loss: 0.5405 - gen_l1_loss: 0.0629
# Epoch 154/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3078 - gen_total_loss: 6.8082 - gen_gan_loss: 0.5424 - gen_l1_loss: 0.0627
# Epoch 155/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3044 - gen_total_loss: 6.8249 - gen_gan_loss: 0.5496 - gen_l1_loss: 0.0628
# Epoch 156/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.3018 - gen_total_loss: 6.7916 - gen_gan_loss: 0.5414 - gen_l1_loss: 0.0625
# Epoch 157/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2693 - gen_total_loss: 6.8903 - gen_gan_loss: 0.5729 - gen_l1_loss: 0.0632
# Epoch 158/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2705 - gen_total_loss: 6.9652 - gen_gan_loss: 0.5963 - gen_l1_loss: 0.0637
# Epoch 159/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2843 - gen_total_loss: 6.8408 - gen_gan_loss: 0.5756 - gen_l1_loss: 0.0627
# Epoch 160/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3422 - gen_total_loss: 6.7317 - gen_gan_loss: 0.5454 - gen_l1_loss: 0.0619
# Epoch 161/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2838 - gen_total_loss: 6.8222 - gen_gan_loss: 0.5636 - gen_l1_loss: 0.0626
# Epoch 162/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2877 - gen_total_loss: 6.7796 - gen_gan_loss: 0.5596 - gen_l1_loss: 0.0622
# Epoch 163/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2748 - gen_total_loss: 6.8371 - gen_gan_loss: 0.5820 - gen_l1_loss: 0.0626
# Epoch 164/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2836 - gen_total_loss: 6.8480 - gen_gan_loss: 0.5775 - gen_l1_loss: 0.0627
# Epoch 165/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2789 - gen_total_loss: 6.8417 - gen_gan_loss: 0.5813 - gen_l1_loss: 0.0626
# Epoch 166/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2759 - gen_total_loss: 6.8475 - gen_gan_loss: 0.5924 - gen_l1_loss: 0.0626
# Epoch 167/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2865 - gen_total_loss: 6.8664 - gen_gan_loss: 0.5696 - gen_l1_loss: 0.0630
# Epoch 168/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2803 - gen_total_loss: 6.8194 - gen_gan_loss: 0.5948 - gen_l1_loss: 0.0622
# Epoch 169/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2971 - gen_total_loss: 6.8235 - gen_gan_loss: 0.5830 - gen_l1_loss: 0.0624
# Epoch 170/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2725 - gen_total_loss: 6.8359 - gen_gan_loss: 0.5885 - gen_l1_loss: 0.0625
# Epoch 171/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2689 - gen_total_loss: 6.8045 - gen_gan_loss: 0.5914 - gen_l1_loss: 0.0621
# Epoch 172/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4844 - gen_total_loss: 6.4441 - gen_gan_loss: 0.5103 - gen_l1_loss: 0.0593
# Epoch 173/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2730 - gen_total_loss: 6.6509 - gen_gan_loss: 0.5414 - gen_l1_loss: 0.0611
# Epoch 174/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2479 - gen_total_loss: 6.7620 - gen_gan_loss: 0.5864 - gen_l1_loss: 0.0618
# Epoch 175/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2746 - gen_total_loss: 6.8054 - gen_gan_loss: 0.5912 - gen_l1_loss: 0.0621
# Epoch 176/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2694 - gen_total_loss: 6.7669 - gen_gan_loss: 0.5961 - gen_l1_loss: 0.0617
# Epoch 177/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2372 - gen_total_loss: 6.8658 - gen_gan_loss: 0.6177 - gen_l1_loss: 0.0625
# Epoch 178/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2593 - gen_total_loss: 6.8441 - gen_gan_loss: 0.6123 - gen_l1_loss: 0.0623
# Epoch 179/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2673 - gen_total_loss: 6.7878 - gen_gan_loss: 0.5888 - gen_l1_loss: 0.0620
# Epoch 180/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2713 - gen_total_loss: 6.7745 - gen_gan_loss: 0.6066 - gen_l1_loss: 0.0617
# Epoch 181/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3104 - gen_total_loss: 6.6903 - gen_gan_loss: 0.5678 - gen_l1_loss: 0.0612
# Epoch 182/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3559 - gen_total_loss: 6.5519 - gen_gan_loss: 0.5361 - gen_l1_loss: 0.0602
# Epoch 183/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2606 - gen_total_loss: 6.6986 - gen_gan_loss: 0.5767 - gen_l1_loss: 0.0612
# Epoch 184/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2656 - gen_total_loss: 6.7524 - gen_gan_loss: 0.6140 - gen_l1_loss: 0.0614
# Epoch 185/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2780 - gen_total_loss: 6.7168 - gen_gan_loss: 0.5804 - gen_l1_loss: 0.0614
# Epoch 186/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2895 - gen_total_loss: 6.7027 - gen_gan_loss: 0.5656 - gen_l1_loss: 0.0614
# Epoch 187/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2799 - gen_total_loss: 6.7084 - gen_gan_loss: 0.5965 - gen_l1_loss: 0.0611
# Epoch 188/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2706 - gen_total_loss: 6.6946 - gen_gan_loss: 0.5818 - gen_l1_loss: 0.0611
# Epoch 189/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2736 - gen_total_loss: 6.7128 - gen_gan_loss: 0.5804 - gen_l1_loss: 0.0613
# Epoch 190/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2789 - gen_total_loss: 6.6820 - gen_gan_loss: 0.5879 - gen_l1_loss: 0.0609
# Epoch 191/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2736 - gen_total_loss: 6.7093 - gen_gan_loss: 0.5883 - gen_l1_loss: 0.0612
# Epoch 192/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2634 - gen_total_loss: 6.7333 - gen_gan_loss: 0.5793 - gen_l1_loss: 0.0615
# Epoch 193/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2968 - gen_total_loss: 6.6950 - gen_gan_loss: 0.5900 - gen_l1_loss: 0.0611
# Epoch 194/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.9378 - gen_total_loss: 6.8763 - gen_gan_loss: 0.8313 - gen_l1_loss: 0.0605
# Epoch 195/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.4498 - gen_total_loss: 5.7509 - gen_gan_loss: 0.2920 - gen_l1_loss: 0.0546
# Epoch 196/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.4090 - gen_total_loss: 5.7671 - gen_gan_loss: 0.3822 - gen_l1_loss: 0.0538
# Epoch 197/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3966 - gen_total_loss: 5.8478 - gen_gan_loss: 0.3980 - gen_l1_loss: 0.0545
# Epoch 198/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4041 - gen_total_loss: 5.9226 - gen_gan_loss: 0.4000 - gen_l1_loss: 0.0552
# Epoch 199/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4102 - gen_total_loss: 5.9414 - gen_gan_loss: 0.3786 - gen_l1_loss: 0.0556
# Epoch 200/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.4156 - gen_total_loss: 5.9614 - gen_gan_loss: 0.3699 - gen_l1_loss: 0.0559
# Epoch 00200: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 200E
# 109/109 [==============================] - 38s 348ms/step - d_loss: 0.4158 - gen_total_loss: 5.9620 - gen_gan_loss: 0.3696 - gen_l1_loss: 0.0559
# Epoch 201/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4174 - gen_total_loss: 5.9940 - gen_gan_loss: 0.3590 - gen_l1_loss: 0.0564
# Epoch 202/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.4141 - gen_total_loss: 6.0113 - gen_gan_loss: 0.3776 - gen_l1_loss: 0.0563
# Epoch 203/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3892 - gen_total_loss: 6.0825 - gen_gan_loss: 0.4292 - gen_l1_loss: 0.0565
# Epoch 204/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3216 - gen_total_loss: 6.2096 - gen_gan_loss: 0.4967 - gen_l1_loss: 0.0571
# Epoch 205/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2615 - gen_total_loss: 6.3708 - gen_gan_loss: 0.5516 - gen_l1_loss: 0.0582
# Epoch 206/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2735 - gen_total_loss: 6.4922 - gen_gan_loss: 0.5941 - gen_l1_loss: 0.0590
# Epoch 207/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2622 - gen_total_loss: 6.4868 - gen_gan_loss: 0.5737 - gen_l1_loss: 0.0591
# Epoch 208/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2295 - gen_total_loss: 6.6008 - gen_gan_loss: 0.6104 - gen_l1_loss: 0.0599
# Epoch 209/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2604 - gen_total_loss: 6.6188 - gen_gan_loss: 0.6208 - gen_l1_loss: 0.0600
# Epoch 210/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2567 - gen_total_loss: 6.5606 - gen_gan_loss: 0.5807 - gen_l1_loss: 0.0598
# Epoch 211/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2750 - gen_total_loss: 6.6158 - gen_gan_loss: 0.6317 - gen_l1_loss: 0.0598
# Epoch 212/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2914 - gen_total_loss: 6.4657 - gen_gan_loss: 0.5746 - gen_l1_loss: 0.0589
# Epoch 213/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2364 - gen_total_loss: 6.5636 - gen_gan_loss: 0.6006 - gen_l1_loss: 0.0596
# Epoch 214/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2597 - gen_total_loss: 6.5628 - gen_gan_loss: 0.5953 - gen_l1_loss: 0.0597
# Epoch 215/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2536 - gen_total_loss: 6.5573 - gen_gan_loss: 0.5980 - gen_l1_loss: 0.0596
# Epoch 216/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2600 - gen_total_loss: 6.5626 - gen_gan_loss: 0.6002 - gen_l1_loss: 0.0596
# Epoch 217/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2692 - gen_total_loss: 6.5760 - gen_gan_loss: 0.6086 - gen_l1_loss: 0.0597
# Epoch 218/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2507 - gen_total_loss: 6.5750 - gen_gan_loss: 0.5937 - gen_l1_loss: 0.0598
# Epoch 219/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2798 - gen_total_loss: 6.5436 - gen_gan_loss: 0.5961 - gen_l1_loss: 0.0595
# Epoch 220/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3201 - gen_total_loss: 6.4642 - gen_gan_loss: 0.5701 - gen_l1_loss: 0.0589
# Epoch 221/300
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2684 - gen_total_loss: 6.4847 - gen_gan_loss: 0.5686 - gen_l1_loss: 0.0592
# Epoch 222/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3020 - gen_total_loss: 6.4996 - gen_gan_loss: 0.5829 - gen_l1_loss: 0.0592
# Epoch 223/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2738 - gen_total_loss: 6.4483 - gen_gan_loss: 0.5580 - gen_l1_loss: 0.0589
# Epoch 224/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2839 - gen_total_loss: 6.4687 - gen_gan_loss: 0.5714 - gen_l1_loss: 0.0590
# Epoch 225/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2880 - gen_total_loss: 6.4827 - gen_gan_loss: 0.5763 - gen_l1_loss: 0.0591
# Epoch 226/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2841 - gen_total_loss: 6.4840 - gen_gan_loss: 0.5804 - gen_l1_loss: 0.0590
# Epoch 227/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2716 - gen_total_loss: 6.4966 - gen_gan_loss: 0.5807 - gen_l1_loss: 0.0592
# Epoch 228/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2808 - gen_total_loss: 6.4632 - gen_gan_loss: 0.5618 - gen_l1_loss: 0.0590
# Epoch 229/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2999 - gen_total_loss: 6.4756 - gen_gan_loss: 0.5889 - gen_l1_loss: 0.0589
# Epoch 230/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2602 - gen_total_loss: 6.4700 - gen_gan_loss: 0.5786 - gen_l1_loss: 0.0589
# Epoch 231/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2706 - gen_total_loss: 6.4971 - gen_gan_loss: 0.5920 - gen_l1_loss: 0.0591
# Epoch 232/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3003 - gen_total_loss: 6.4676 - gen_gan_loss: 0.5821 - gen_l1_loss: 0.0589
# Epoch 233/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2633 - gen_total_loss: 6.4729 - gen_gan_loss: 0.5774 - gen_l1_loss: 0.0590
# Epoch 234/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.3096 - gen_total_loss: 6.4302 - gen_gan_loss: 0.5824 - gen_l1_loss: 0.0585
# Epoch 235/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2660 - gen_total_loss: 6.4655 - gen_gan_loss: 0.5850 - gen_l1_loss: 0.0588
# Epoch 236/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2713 - gen_total_loss: 6.4572 - gen_gan_loss: 0.5810 - gen_l1_loss: 0.0588
# Epoch 237/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.3701 - gen_total_loss: 6.3716 - gen_gan_loss: 0.5672 - gen_l1_loss: 0.0580
# Epoch 238/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2666 - gen_total_loss: 6.4383 - gen_gan_loss: 0.5764 - gen_l1_loss: 0.0586
# Epoch 239/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2765 - gen_total_loss: 6.4269 - gen_gan_loss: 0.5763 - gen_l1_loss: 0.0585
# Epoch 240/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2574 - gen_total_loss: 6.5003 - gen_gan_loss: 0.5869 - gen_l1_loss: 0.0591
# Epoch 241/300
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2874 - gen_total_loss: 6.4672 - gen_gan_loss: 0.5859 - gen_l1_loss: 0.0588
# Epoch 242/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2548 - gen_total_loss: 6.5003 - gen_gan_loss: 0.5963 - gen_l1_loss: 0.0590
# Epoch 243/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2766 - gen_total_loss: 6.4499 - gen_gan_loss: 0.5822 - gen_l1_loss: 0.0587
# Epoch 244/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2816 - gen_total_loss: 6.4659 - gen_gan_loss: 0.5869 - gen_l1_loss: 0.0588
# Epoch 245/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.4533 - gen_total_loss: 6.2257 - gen_gan_loss: 0.5456 - gen_l1_loss: 0.0568
# Epoch 246/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.3514 - gen_total_loss: 6.0765 - gen_gan_loss: 0.4501 - gen_l1_loss: 0.0563
# Epoch 247/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2677 - gen_total_loss: 6.3098 - gen_gan_loss: 0.5496 - gen_l1_loss: 0.0576
# Epoch 248/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2822 - gen_total_loss: 6.3764 - gen_gan_loss: 0.5672 - gen_l1_loss: 0.0581
# Epoch 249/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2729 - gen_total_loss: 6.4418 - gen_gan_loss: 0.5971 - gen_l1_loss: 0.0584
# Epoch 250/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.2577 - gen_total_loss: 6.4237 - gen_gan_loss: 0.5842 - gen_l1_loss: 0.0584
# Epoch 00250: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 250E
# 109/109 [==============================] - 38s 346ms/step - d_loss: 0.2577 - gen_total_loss: 6.4211 - gen_gan_loss: 0.5816 - gen_l1_loss: 0.0584
# Epoch 251/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2732 - gen_total_loss: 6.4621 - gen_gan_loss: 0.5946 - gen_l1_loss: 0.0587
# Epoch 252/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2571 - gen_total_loss: 6.4032 - gen_gan_loss: 0.5848 - gen_l1_loss: 0.0582
# Epoch 253/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.3043 - gen_total_loss: 6.3841 - gen_gan_loss: 0.5779 - gen_l1_loss: 0.0581
# Epoch 254/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2381 - gen_total_loss: 6.4418 - gen_gan_loss: 0.5995 - gen_l1_loss: 0.0584
# Epoch 255/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2753 - gen_total_loss: 6.4657 - gen_gan_loss: 0.6024 - gen_l1_loss: 0.0586
# Epoch 256/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2694 - gen_total_loss: 6.4341 - gen_gan_loss: 0.5933 - gen_l1_loss: 0.0584
# Epoch 257/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2758 - gen_total_loss: 6.4291 - gen_gan_loss: 0.6031 - gen_l1_loss: 0.0583
# Epoch 258/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2831 - gen_total_loss: 6.3901 - gen_gan_loss: 0.5744 - gen_l1_loss: 0.0582
# Epoch 259/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2774 - gen_total_loss: 6.4249 - gen_gan_loss: 0.5983 - gen_l1_loss: 0.0583
# Epoch 260/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2694 - gen_total_loss: 6.4109 - gen_gan_loss: 0.5936 - gen_l1_loss: 0.0582
# Epoch 261/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2568 - gen_total_loss: 6.4428 - gen_gan_loss: 0.5997 - gen_l1_loss: 0.0584
# Epoch 262/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2845 - gen_total_loss: 6.4035 - gen_gan_loss: 0.5780 - gen_l1_loss: 0.0583
# Epoch 263/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2558 - gen_total_loss: 6.4256 - gen_gan_loss: 0.5990 - gen_l1_loss: 0.0583
# Epoch 264/300
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.3021 - gen_total_loss: 6.4046 - gen_gan_loss: 0.5983 - gen_l1_loss: 0.0581
# Epoch 265/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2456 - gen_total_loss: 6.4291 - gen_gan_loss: 0.5984 - gen_l1_loss: 0.0583
# Epoch 266/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2926 - gen_total_loss: 6.4184 - gen_gan_loss: 0.6011 - gen_l1_loss: 0.0582
# Epoch 267/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2703 - gen_total_loss: 6.3863 - gen_gan_loss: 0.5913 - gen_l1_loss: 0.0579
# Epoch 268/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2476 - gen_total_loss: 6.4493 - gen_gan_loss: 0.6069 - gen_l1_loss: 0.0584
# Epoch 269/300
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.2536 - gen_total_loss: 6.4345 - gen_gan_loss: 0.6089 - gen_l1_loss: 0.0583
# Epoch 270/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2593 - gen_total_loss: 6.4553 - gen_gan_loss: 0.6259 - gen_l1_loss: 0.0583
# Epoch 271/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2569 - gen_total_loss: 6.4442 - gen_gan_loss: 0.6065 - gen_l1_loss: 0.0584
# Epoch 272/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2616 - gen_total_loss: 6.4463 - gen_gan_loss: 0.6076 - gen_l1_loss: 0.0584
# Epoch 273/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2808 - gen_total_loss: 6.4175 - gen_gan_loss: 0.5996 - gen_l1_loss: 0.0582
# Epoch 274/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2496 - gen_total_loss: 6.4221 - gen_gan_loss: 0.6046 - gen_l1_loss: 0.0582
# Epoch 275/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2774 - gen_total_loss: 6.3672 - gen_gan_loss: 0.5910 - gen_l1_loss: 0.0578
# Epoch 276/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2884 - gen_total_loss: 6.3937 - gen_gan_loss: 0.5939 - gen_l1_loss: 0.0580
# Epoch 277/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2822 - gen_total_loss: 6.3730 - gen_gan_loss: 0.5917 - gen_l1_loss: 0.0578
# Epoch 278/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2683 - gen_total_loss: 6.3980 - gen_gan_loss: 0.6029 - gen_l1_loss: 0.0580
# Epoch 279/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2437 - gen_total_loss: 6.3873 - gen_gan_loss: 0.6180 - gen_l1_loss: 0.0577
# Epoch 280/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2533 - gen_total_loss: 6.4293 - gen_gan_loss: 0.6064 - gen_l1_loss: 0.0582
# Epoch 281/300
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.2705 - gen_total_loss: 6.4361 - gen_gan_loss: 0.6091 - gen_l1_loss: 0.0583
# Epoch 282/300
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2724 - gen_total_loss: 6.4000 - gen_gan_loss: 0.6060 - gen_l1_loss: 0.0579
# Epoch 283/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2565 - gen_total_loss: 6.4047 - gen_gan_loss: 0.6213 - gen_l1_loss: 0.0578
# Epoch 284/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2588 - gen_total_loss: 6.4021 - gen_gan_loss: 0.6120 - gen_l1_loss: 0.0579
# Epoch 285/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2353 - gen_total_loss: 6.4453 - gen_gan_loss: 0.6444 - gen_l1_loss: 0.0580
# Epoch 286/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2386 - gen_total_loss: 6.4654 - gen_gan_loss: 0.6392 - gen_l1_loss: 0.0583
# Epoch 287/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2285 - gen_total_loss: 6.4588 - gen_gan_loss: 0.6327 - gen_l1_loss: 0.0583
# Epoch 288/300
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2685 - gen_total_loss: 6.4163 - gen_gan_loss: 0.6257 - gen_l1_loss: 0.0579
# Epoch 289/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2453 - gen_total_loss: 6.4260 - gen_gan_loss: 0.6293 - gen_l1_loss: 0.0580
# Epoch 290/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2395 - gen_total_loss: 6.4389 - gen_gan_loss: 0.6271 - gen_l1_loss: 0.0581
# Epoch 291/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2289 - gen_total_loss: 6.4801 - gen_gan_loss: 0.6418 - gen_l1_loss: 0.0584
# Epoch 292/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2736 - gen_total_loss: 6.4380 - gen_gan_loss: 0.6287 - gen_l1_loss: 0.0581
# Epoch 293/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2401 - gen_total_loss: 6.4226 - gen_gan_loss: 0.6317 - gen_l1_loss: 0.0579
# Epoch 294/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2284 - gen_total_loss: 6.4676 - gen_gan_loss: 0.6334 - gen_l1_loss: 0.0583
# Epoch 295/300
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2847 - gen_total_loss: 6.4113 - gen_gan_loss: 0.6258 - gen_l1_loss: 0.0579
# Epoch 296/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2366 - gen_total_loss: 6.4517 - gen_gan_loss: 0.6273 - gen_l1_loss: 0.0582
# Epoch 297/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2799 - gen_total_loss: 6.4010 - gen_gan_loss: 0.6183 - gen_l1_loss: 0.0578
# Epoch 298/300
# 109/109 [==============================] - 36s 333ms/step - d_loss: 0.2358 - gen_total_loss: 6.4163 - gen_gan_loss: 0.6360 - gen_l1_loss: 0.0578
# Epoch 299/300
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2434 - gen_total_loss: 6.4449 - gen_gan_loss: 0.6323 - gen_l1_loss: 0.0581
# Epoch 300/300
# 109/109 [==============================] - ETA: 0s - d_loss: 0.4846 - gen_total_loss: 6.3717 - gen_gan_loss: 0.6658 - gen_l1_loss: 0.0571
# Epoch 00300: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 300E
# 109/109 [==============================] - 38s 347ms/step - d_loss: 0.4837 - gen_total_loss: 6.3658 - gen_gan_loss: 0.6639 - gen_l1_loss: 0.0570

# %%
# model.save_weights("models/test/test 25")
# model.load_weights("models/test/test")

model.save(str(MODELS_DIR / RUN_NAME) + f' {EPOCHS}E')
# Out:
# INFO:tensorflow:Assets written to: c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 300E\assets

# %% [markdown]
# - Check that neither the generator nor the discriminator model has "won". If either the gen_gan_loss or the disc_loss gets very low, it's an indicator that this model is dominating the other, and you are not successfully training the combined model.
# - The value log(2) = 0.69 is a good reference point for these losses, as it indicates a perplexity of 2 - the discriminator is, on average, equally uncertain about the two options.
# - For the disc_loss, a value below 0.69 means the discriminator is doing better than random on the combined set of real and generated images.
# - For the gen_gan_loss, a value below 0.69 means the generator is doing better than random at fooling the discriminator.
# - As training progresses, the gen_l1_loss should go down.
#
# Discriminator loss is too high but is reducing after many (50) epochs, try reducing the label smoothing. l1_loss has slowed reducing. gan_loss and total_loss are roughly flat.

# %%
if USE_WANDB:
    callbacks = [
        DisplayCallback(steps_per_epoch=STEPS_PER_EPOCH, continue_training=True, patch_cmap=cmap),
        WandbCallback(),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=str(MODELS_DIR / RUN_NAME) +' {epoch:03d}E',
            verbose=1, 
            save_weights_only=False,
            save_freq= int(50 * STEPS_PER_EPOCH)) # save every 50 epochs
        ]
else:
    callbacks = []

# model.compile(
#     tf.keras.optimizers.Adam(lr=G_LEARNING_RATE, beta_1=G_BETA_1), # g_optimizer
#     tf.keras.optimizers.Adam(lr=D_LEARNING_RATE, beta_1=D_BETA_1), # d_optimizer
#     generator_loss, discriminator_loss)

extra_epochs = 200

# continue training
history2 = model.fit(
    train_ds,
    epochs=history.epoch[-1]+1+extra_epochs,
    initial_epoch=history.epoch[-1]+1,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_steps=VALIDATION_STEPS,
    validation_data=valid_ds,
    callbacks=callbacks)
# Out:
# Epoch 301/500
#   6/109 [>.............................] - ETA: 33s - d_loss: 0.3422 - gen_total_loss: 5.6851 - gen_gan_loss: 0.3961 - gen_l1_loss: 0.0529WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1276s vs `on_train_batch_end` time: 0.1932s). Check your callbacks.
# 109/109 [==============================] - 37s 342ms/step - d_loss: 0.3517 - gen_total_loss: 5.9434 - gen_gan_loss: 0.4359 - gen_l1_loss: 0.0551 - val_loss: 0.0000e+00
# Epoch 302/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.3134 - gen_total_loss: 6.0676 - gen_gan_loss: 0.4965 - gen_l1_loss: 0.0557 - val_loss: 0.0000e+00
# Epoch 303/500
# 109/109 [==============================] - 37s 341ms/step - d_loss: 0.2371 - gen_total_loss: 6.3097 - gen_gan_loss: 0.6121 - gen_l1_loss: 0.0570 - val_loss: 0.0000e+00
# Epoch 304/500
# 109/109 [==============================] - 37s 344ms/step - d_loss: 0.2196 - gen_total_loss: 6.3873 - gen_gan_loss: 0.6233 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 305/500
# 109/109 [==============================] - 38s 348ms/step - d_loss: 0.2306 - gen_total_loss: 6.4199 - gen_gan_loss: 0.6485 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 306/500
# 109/109 [==============================] - 36s 335ms/step - d_loss: 0.2081 - gen_total_loss: 6.4286 - gen_gan_loss: 0.6410 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 307/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2228 - gen_total_loss: 6.4527 - gen_gan_loss: 0.6649 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 308/500
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.2224 - gen_total_loss: 6.4832 - gen_gan_loss: 0.6620 - gen_l1_loss: 0.0582 - val_loss: 0.0000e+00
# Epoch 309/500
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.2198 - gen_total_loss: 6.4473 - gen_gan_loss: 0.6484 - gen_l1_loss: 0.0580 - val_loss: 0.0000e+00
# Epoch 310/500
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2307 - gen_total_loss: 6.4420 - gen_gan_loss: 0.6515 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 311/500
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2556 - gen_total_loss: 6.3898 - gen_gan_loss: 0.6467 - gen_l1_loss: 0.0574 - val_loss: 0.0000e+00
# Epoch 312/500
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2055 - gen_total_loss: 6.4454 - gen_gan_loss: 0.6523 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 313/500
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2302 - gen_total_loss: 6.4714 - gen_gan_loss: 0.6499 - gen_l1_loss: 0.0582 - val_loss: 0.0000e+00
# Epoch 314/500
# 109/109 [==============================] - 35s 320ms/step - d_loss: 0.2810 - gen_total_loss: 6.3566 - gen_gan_loss: 0.6377 - gen_l1_loss: 0.0572 - val_loss: 0.0000e+00
# Epoch 315/500
# 109/109 [==============================] - 35s 326ms/step - d_loss: 0.2221 - gen_total_loss: 6.4274 - gen_gan_loss: 0.6531 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 316/500
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2497 - gen_total_loss: 6.3800 - gen_gan_loss: 0.6225 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 317/500
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2069 - gen_total_loss: 6.4529 - gen_gan_loss: 0.6685 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 318/500
# 109/109 [==============================] - 36s 327ms/step - d_loss: 0.2155 - gen_total_loss: 6.4767 - gen_gan_loss: 0.6595 - gen_l1_loss: 0.0582 - val_loss: 0.0000e+00
# Epoch 319/500
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2527 - gen_total_loss: 6.4016 - gen_gan_loss: 0.6487 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 320/500
# 109/109 [==============================] - 35s 325ms/step - d_loss: 0.2276 - gen_total_loss: 6.4026 - gen_gan_loss: 0.6521 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 321/500
# 109/109 [==============================] - 35s 324ms/step - d_loss: 0.2189 - gen_total_loss: 6.4767 - gen_gan_loss: 0.6609 - gen_l1_loss: 0.0582 - val_loss: 0.0000e+00
# Epoch 322/500
# 109/109 [==============================] - 35s 319ms/step - d_loss: 0.2250 - gen_total_loss: 6.4487 - gen_gan_loss: 0.6650 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 323/500
# 109/109 [==============================] - 35s 320ms/step - d_loss: 0.2310 - gen_total_loss: 6.4074 - gen_gan_loss: 0.6468 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 324/500
# 109/109 [==============================] - 35s 321ms/step - d_loss: 0.2391 - gen_total_loss: 6.4096 - gen_gan_loss: 0.6527 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 325/500
# 109/109 [==============================] - 35s 324ms/step - d_loss: 0.2203 - gen_total_loss: 6.4512 - gen_gan_loss: 0.6643 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 326/500
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2354 - gen_total_loss: 6.4534 - gen_gan_loss: 0.6607 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 327/500
# 109/109 [==============================] - 37s 337ms/step - d_loss: 0.2056 - gen_total_loss: 6.4485 - gen_gan_loss: 0.6562 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 328/500
# 109/109 [==============================] - 36s 328ms/step - d_loss: 0.2479 - gen_total_loss: 6.4392 - gen_gan_loss: 0.6626 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 329/500
# 109/109 [==============================] - 37s 337ms/step - d_loss: 0.2226 - gen_total_loss: 6.4403 - gen_gan_loss: 0.6697 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 330/500
# 109/109 [==============================] - 37s 339ms/step - d_loss: 0.2054 - gen_total_loss: 6.4241 - gen_gan_loss: 0.6674 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 331/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2349 - gen_total_loss: 6.4716 - gen_gan_loss: 0.6844 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 332/500
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2240 - gen_total_loss: 6.4452 - gen_gan_loss: 0.6716 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 333/500
# 109/109 [==============================] - 36s 329ms/step - d_loss: 0.2291 - gen_total_loss: 6.4123 - gen_gan_loss: 0.6609 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 334/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2154 - gen_total_loss: 6.4343 - gen_gan_loss: 0.6662 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 335/500
# 109/109 [==============================] - 36s 326ms/step - d_loss: 0.2195 - gen_total_loss: 6.4617 - gen_gan_loss: 0.6680 - gen_l1_loss: 0.0579 - val_loss: 0.0000e+00
# Epoch 336/500
# 109/109 [==============================] - 35s 323ms/step - d_loss: 0.2031 - gen_total_loss: 6.4529 - gen_gan_loss: 0.6769 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 337/500
# 109/109 [==============================] - 35s 322ms/step - d_loss: 0.2054 - gen_total_loss: 6.4496 - gen_gan_loss: 0.6901 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 338/500
# 109/109 [==============================] - 37s 337ms/step - d_loss: 0.2356 - gen_total_loss: 6.4425 - gen_gan_loss: 0.6765 - gen_l1_loss: 0.0577 - val_loss: 0.0000e+00
# Epoch 339/500
# 109/109 [==============================] - 37s 337ms/step - d_loss: 0.2089 - gen_total_loss: 6.4507 - gen_gan_loss: 0.6745 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 340/500
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.5527 - gen_total_loss: 6.1155 - gen_gan_loss: 0.5945 - gen_l1_loss: 0.0552 - val_loss: 0.0000e+00
# Epoch 341/500
# 109/109 [==============================] - 37s 341ms/step - d_loss: 0.3162 - gen_total_loss: 6.0725 - gen_gan_loss: 0.5026 - gen_l1_loss: 0.0557 - val_loss: 0.0000e+00
# Epoch 342/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2276 - gen_total_loss: 6.2885 - gen_gan_loss: 0.6156 - gen_l1_loss: 0.0567 - val_loss: 0.0000e+00
# Epoch 343/500
# 109/109 [==============================] - 36s 334ms/step - d_loss: 0.2290 - gen_total_loss: 6.3305 - gen_gan_loss: 0.6370 - gen_l1_loss: 0.0569 - val_loss: 0.0000e+00
# Epoch 344/500
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.2032 - gen_total_loss: 6.3663 - gen_gan_loss: 0.6649 - gen_l1_loss: 0.0570 - val_loss: 0.0000e+00
# Epoch 345/500
# 109/109 [==============================] - 36s 331ms/step - d_loss: 0.1750 - gen_total_loss: 6.4632 - gen_gan_loss: 0.7023 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 346/500
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2145 - gen_total_loss: 6.4161 - gen_gan_loss: 0.6624 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 347/500
# 109/109 [==============================] - 37s 338ms/step - d_loss: 0.1869 - gen_total_loss: 6.4650 - gen_gan_loss: 0.7021 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 348/500
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2071 - gen_total_loss: 6.4550 - gen_gan_loss: 0.6962 - gen_l1_loss: 0.0576 - val_loss: 0.0000e+00
# Epoch 349/500
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.2698 - gen_total_loss: 6.3477 - gen_gan_loss: 0.6587 - gen_l1_loss: 0.0569 - val_loss: 0.0000e+00
# Epoch 350/500
# 109/109 [==============================] - ETA: 0s - d_loss: 0.1821 - gen_total_loss: 6.4351 - gen_gan_loss: 0.6851 - gen_l1_loss: 0.0575
# Epoch 00350: saving model to c:\Users\ylene\Documents\Work\Projects\sketch2frog\sketch2frog\models\2021-09-25 0014 350E
# 109/109 [==============================] - 38s 347ms/step - d_loss: 0.1819 - gen_total_loss: 6.4354 - gen_gan_loss: 0.6829 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 351/500
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2356 - gen_total_loss: 6.4023 - gen_gan_loss: 0.6690 - gen_l1_loss: 0.0573 - val_loss: 0.0000e+00
# Epoch 352/500
# 109/109 [==============================] - 36s 332ms/step - d_loss: 0.1892 - gen_total_loss: 6.4431 - gen_gan_loss: 0.6913 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 353/500
# 109/109 [==============================] - 37s 336ms/step - d_loss: 0.1830 - gen_total_loss: 6.4747 - gen_gan_loss: 0.6935 - gen_l1_loss: 0.0578 - val_loss: 0.0000e+00
# Epoch 354/500
# 109/109 [==============================] - 37s 340ms/step - d_loss: 0.2199 - gen_total_loss: 6.3971 - gen_gan_loss: 0.6857 - gen_l1_loss: 0.0571 - val_loss: 0.0000e+00
# Epoch 355/500
# 109/109 [==============================] - 36s 326ms/step - d_loss: 0.2138 - gen_total_loss: 6.4476 - gen_gan_loss: 0.6944 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 356/500
# 109/109 [==============================] - 36s 330ms/step - d_loss: 0.2012 - gen_total_loss: 6.4457 - gen_gan_loss: 0.6988 - gen_l1_loss: 0.0575 - val_loss: 0.0000e+00
# Epoch 357/500
# 109/109 [==============================] - 36s 326ms/step - d_loss: 0.1974 - gen_total_loss: 6.4276 - gen_gan_loss: 0.6926 - gen_l1_loss: 0.0573 - val_loss: 0.0000e+00
# Epoch 358/500
#  46/109 [===========>..................] - ETA: 20s - d_loss: 0.2248 - gen_total_loss: 6.4248 - gen_gan_loss: 0.6806 - gen_l1_loss: 0.0574

# %%
# model.save(str(MODELS_DIR / RUN_NAME) + f' {history.epoch[-1]+1+extra_epochs}E')
model.save(str(MODELS_DIR / RUN_NAME) + f' 500E')
# Out:
# INFO:tensorflow:Assets written to: c:\Users\ylene\Documents\Work\Projects\sketch2frog\models\2021-09-16 1711 300E\assets

# %% [markdown]
# # Load Saved Model

# %%
RUN_NAME = '2021-09-25 0014'
# model = tf.keras.models.load_model(MODELS_DIR / RUN_NAME / '2021-09-16 2101 500E')

model.load_weights(MODELS_DIR / '2021-09-16 2101 - checkpoints' / '2021-09-16 2101 500E')

# %%
def plot_pred_batch(model, dataset, save=False, to_plot=8, size=2, show=True):
    """
    Take to_plot images from dataset.
    Print the input image, the target image and predicted image from model generator.
    Save the image to "save" if desired, and print if show=True.
    size scales the figure
    """

    # make a directory to save the results if necessary
    if save and not os.path.exists(save.parent):
        os.makedirs(viz_path)
        
    # no ticks
    subplot_options = dict(xticks=[], yticks=[])
        
    # take a batch and make predictions
    for x_batch, y_batch in dataset.take(1):
        
        # if one batch has fewer than to_plot then do 1 whole batch
        to_plot = min(to_plot, x_batch.shape[0])
        
        # get predictions and rescale to [0,1]
        preds = (model.generator(x_batch).numpy()+1)/2
        
        x_batch = x_batch.numpy()
        y_batch = (y_batch.numpy()+1)/2
        
        # prepare figure
        fig = plt.Figure(figsize=[size*to_plot, size*3], constrained_layout=True)
        gs = fig.add_gridspec(3,to_plot)
        
        # columns
        for i, imgs in enumerate(zip(x_batch, y_batch, preds)):
            # rows
            for j, img in enumerate(imgs):
                ax = fig.add_subplot(gs[j,i], **subplot_options)
                
                # generator input has 1 channel - b&w sketch
                ax.imshow(img, cmap='gray' if j==0 else 'viridis')
                
                # add titles to left side
                if i==0:
                    ax.set_ylabel(['sketch','target','prediction'][j])
                    
            # stop once plotted enough
            if i == to_plot-1:
                break
        
        # colour between plots
        fig.set_facecolor('white')
        
        if save:
            fig.savefig(str(save))
        if show:
            display(fig)
    
plot_pred_batch(model, train_ds, save=False, to_plot=8, size=2, show=True)
plot_pred_batch(model, valid_ds, save=False, to_plot=8, size=2, show=True)

# %% [markdown]
# # Exploring Results

# %% [markdown]
# ## PatchGAN Output

# %%
def plot_patches(model, sketch, image, patch_cmap='viridis', patch_vmin=-0.5, patch_vmax=1.5):
    
    # Prepare the sub figures
    fig = plt.figure(constrained_layout=True, figsize=[12,8])
    gs0 = fig.add_gridspec(2,1, height_ratios=[1,2], hspace=0)

    gs00 = gs0[0].subgridspec(1,5)
    gs10 = gs0[1].subgridspec(2,5, hspace=0)

    # no ticks
    subplot_options = dict(xticks=[], yticks=[])

    # top 2
    ax1 = fig.add_subplot(gs00[1], title='Sketch', **subplot_options)
    ax2 = fig.add_subplot(gs00[3], title='Image', **subplot_options)

    # Fake generator Ouputs
    ax3 = fig.add_subplot(gs10[0,0], title='Random', **subplot_options)
    ax4 = fig.add_subplot(gs10[0,1], title='Zeros', **subplot_options)
    ax5 = fig.add_subplot(gs10[0,2], title='Identity Generator', **subplot_options)
    ax6 = fig.add_subplot(gs10[0,3], title='Model Generator', **subplot_options)
    ax7 = fig.add_subplot(gs10[0,4], title='Perfect Generator', **subplot_options)
    
    # PatchGan outputs
    ax8  = fig.add_subplot(gs10[1,0], **subplot_options)
    ax9  = fig.add_subplot(gs10[1,1], **subplot_options)
    ax10 = fig.add_subplot(gs10[1,2], **subplot_options)
    ax11 = fig.add_subplot(gs10[1,3], **subplot_options)
    ax12 = fig.add_subplot(gs10[1,4], **subplot_options)
    
    # plot the images
    ax1.imshow(sketch[0].numpy(), cmap='gray')
    ax2.imshow((image[0].numpy()+1)/2)
    
    # create random image - images are [-1,1]
    rand_img = tf.random.uniform(image.shape, -1, 1)
    rand_patch = model.discriminator([sketch, rand_img])
    ax3.imshow((rand_img[0].numpy()+1)/2)
    ax8.imshow(rand_patch[0].numpy(), cmap=patch_cmap, vmin=patch_vmin, vmax=patch_vmax)
    ax8.set_title(rand_patch[0].numpy().mean())
    
    # create image of zeros (img is [-1,1] so "zero" is -1)
    zeros_img = -tf.ones_like(image)
    zeros_patch = model.discriminator([sketch, zeros_img])
    ax4.imshow((zeros_img[0].numpy()+1)/2)
    ax9.imshow(zeros_patch[0].numpy(), cmap=patch_cmap, vmin=patch_vmin, vmax=patch_vmax)
    ax9.set_title(zeros_patch[0].numpy().mean())
    
    # Identity generator
    sketch_rgb = tf.image.grayscale_to_rgb(sketch)*2-1
    ident_patch = model.discriminator([sketch, sketch_rgb])
    ax5.imshow((sketch_rgb[0].numpy()+1)/2)
    ax10.imshow(ident_patch[0].numpy(), cmap=patch_cmap, vmin=patch_vmin, vmax=patch_vmax)
    ax10.set_title(ident_patch[0].numpy().mean())
    
    # model generator
    gen_img = model.generator(sketch)
    gen_img_patch = model.discriminator([sketch, gen_img])
    ax6.imshow((gen_img[0].numpy()+1)/2)
    ax11.imshow(gen_img_patch[0].numpy(), cmap=patch_cmap, vmin=patch_vmin, vmax=patch_vmax)
    ax11.set_title(gen_img_patch[0].numpy().mean())
    
    # Perfect generator
    perfect_patch = model.discriminator([sketch, image])
    ax7.imshow((image[0].numpy()+1)/2)
    im = ax12.imshow(perfect_patch[0].numpy(), cmap=patch_cmap, vmin=patch_vmin, vmax=patch_vmax)
    ax12.set_title(perfect_patch[0].numpy().mean())

    # styling
    cb = fig.colorbar(im, ax=[ax8,ax9,ax10,ax11,ax12], anchor=(0.5,0.5), orientation='horizontal', fraction=.2)
    fig.set_facecolor('white')

    plt.show()
    plt.close()


cmap = viridis_extended()

for x_batch, y_batch in train_ds.take(1):
    plot_patches(model, x_batch[:1], y_batch[:1], patch_cmap=cmap)

# %% [markdown]
# patchgan outputs go way over 1 (>4) and alse well below 0 (<-1).
#
# The colorbar is completely wrong. Colors are set by the final image (im) to get around this I must set the vmin, vmax to sensible values.
#
# Discriminator is performing very poorly, why???
#
# Adjust label smoothing within [0,1] then add sigmoid activation to discriminitor to ensure [0,1].

# %% [markdown]
# ## Bulk examples
#
# Save visualisations for many validation examples.

# %%
def save_bulk_examples(viz_path, n_train=10, n_valid=10, **kwargs):
    """Save many examples from train and valid sets to a folder - viz_patch"""
    
    for i in range(n_train):
        plot_pred_batch(model, train_ds, save=viz_path/'train'/f'{i}', **kwargs)
        
    for i in range(n_valid):
        plot_pred_batch(model, valid_ds, save=viz_path/'valid'/f'{i}', **kwargs)
    
    
viz_path = VIZ_DIR / RUN_NAME /'500E'
# save_bulk_examples(viz_path, to_plot=8, size=2, show=True)

# %% [markdown]
# ## Close WandB

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 28796<br/>Program ended successfully.
# VBox(children=(Label(value=' 43.39MB of 43.39MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.…
# Find user logs for this run at: <code>c:\Users\ylene\Documents\Work\Projects\sketch2frog\notebooks\wandb\run-20210826_204204-3l9qjjow\logs\debug.log</code>
# Find internal logs for this run at: <code>c:\Users\ylene\Documents\Work\Projects\sketch2frog\notebooks\wandb\run-20210826_204204-3l9qjjow\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>10913</td></tr><tr><td>_timestamp</td><td>1630017837</td></tr><tr><td>_step</td><td>298</td></tr><tr><td>epoch</td><td>98</td></tr><tr><td>d_loss_real</td><td>0.01008</td></tr><tr><td>d_loss_fake</td><td>0.17072</td></tr><tr><td>gen_total_loss</td><td>17.80082</td></tr><tr><td>gen_gan_loss</td><td>7.61216</td></tr><tr><td>gen_l1_loss</td><td>0.10189</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>d_loss_real</td><td>█▄▂▃▄▄▃▃▂▂▄▃▃▂▂▁▃▁▂▂▆▁▂▁▁▃▁▁▁▁▁▁▁▁▁▆▂▁▁▁</td></tr><tr><td>d_loss_fake</td><td>▄▃▂▂▃▃▂▃▃▃▃▂▃▂▂▂▄▂▂▁▃▂▂▂▂▃▁▁▁▁▂▁▁▁▁█▁▁▁▂</td></tr><tr><td>gen_total_loss</td><td>▇▄▆▄▆▂▃▁▂▂▁▁▂▂▁▄▃▂▂▄▃▄▄▂▄▄▂▃▁▃▄▄▃▄▅█▄▃▄▆</td></tr><tr><td>gen_gan_loss</td><td>▁▁▂▂▁▁▁▁▁▁▁▁▂▂▂▃▄▃▃▄▄▄▄▃▄▅▃▄▃▃▅▄▄▃▅█▄▃▄▆</td></tr><tr><td>gen_l1_loss</td><td>█▅▇▄▇▃▄▂▃▃▂▂▃▂▁▃▂▂▂▃▁▂▃▁▃▂▁▂▁▂▂▂▂▃▃▃▂▂▃▂</td></tr></table><br/>
# Synced 7 W&B file(s), 201 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">confused-snowball-1</strong>: <a href="https://wandb.ai/yleneb/sketch2frog/runs/3l9qjjow" target="_blank">https://wandb.ai/yleneb/sketch2frog/runs/3l9qjjow</a><br/>
